# %% [markdown]
# # Seaborn
#
# ![seaborn.PNG](data:image/png;base64,...)
#
#
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial

# %%
#Importamos las librerias
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# https://github.com/allisonhorst/palmerpenguins

# %% [markdown]
# # matplotlib vs seaborn

# %%
#Matplotlib orientado a arrays
npoins = 500
xs = np.linspace(0,10,npoins)
ys = np.random.randn(npoins,4).cumsum(axis=0) #4 columnas y 500 lineas y despues suma acumulativa
#Hemos creado 4 random 
ys.shape

plt.plot(xs,ys);

# %%
#Seaborn orientado a dataframe

df = pd.DataFrame(ys, index=xs, columns=list('abcd'))
sns.lineplot(data=df)

# %% [markdown]
# ### Scatter plots

# %%
#Jugueteando con bases de datos
from vega_datasets import data

data.list_datasets()
# Out:
# ['7zip',
#  'airports',
#  'annual-precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2-concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare-dependencies',
#  'flights-10k',
#  'flights-200k',
#  'flights-20k',
#  'flights-2k',
#  'flights-3m',
#  'flights-5k',
#  'flights-airport',
#  'gapminder',
#  'gapminder-health-income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa-electricity',
#  'iris',
#  'jobs',
#  'la-riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal-2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle-temps',
#  'seattle-weather',
#  'sf-temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
#  'unemployment-across-industries',
#  'uniform-2d',
#  'us-10m',
#  'us-employment',
#  'us-state-capitals',
#  'volcano',
#  'weather',
#  'weball26',
#  'wheat',
#  'windvectors',
#  'world-110m',
#  'zipcodes']

# %%
monarchs = data.monarchs()
monarchs
#Reyes de Inglaterra
# Out:
#     commonwealth   end  index        name  start
# 0            NaN  1603      0   Elizabeth   1565
# 1            NaN  1625      1     James I   1603
# 2            NaN  1649      2   Charles I   1625
# 3            1.0  1660      3    Cromwell   1649
# 4            NaN  1685      4  Charles II   1660
# 5            NaN  1689      5    James II   1685
# 6            NaN  1702      6         W&M   1689
# 7            NaN  1714      7        Anne   1702
# 8            NaN  1727      8    George I   1714
# 9            NaN  1760      9   George II   1727
# 10           NaN  1820     10  George III   1760
# 11           NaN  1820     11   George IV   1820

# %%
obesity = data.obesity()
obesity.head(3)
# Out:
#    id   rate state
# 0   1  0.187    AL
# 1   2  0.198    AK
# 2   4  0.133    AZ

# %%
#Guardar un archivo en formato csv
cars.to_csv('cars.csv')

# %%
cars = pd.read_csv('cars.csv')
cars.head()
# Out:
#    Unnamed: 0                       Name  Miles_per_Gallon  Cylinders  \
# 0           0  chevrolet chevelle malibu              18.0          8
# 1           1          buick skylark 320              15.0          8
# 2           2         plymouth satellite              18.0          8
# 3           3              amc rebel sst              16.0          8
# 4           4                ford torino              17.0          8
#
#    Displacement  Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0         307.0       130.0           3504          12.0  1970-01-01    USA
# 1         350.0       165.0           3693          11.5  1970-01-01    USA
# 2         318.0       150.0           3436          11.0  1970-01-01    USA
# 3         304.0       150.0           3433          12.0  1970-01-01    USA
# 4         302.0       140.0           3449          10.5  1970-01-01    USA

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
#Ponemos otro style
sns.set_theme(style='darkgrid')
#Primer plot
sns.relplot(data=cars, x='Miles_per_Gallon', y='Displacement')

#Observamos una relación inversa entre las variables

# %%
sns.relplot(data=cars, 
            x='Miles_per_Gallon', 
            y='Displacement', 
            hue='Origin')

# %%
sns.relplot(data=cars, 
            x='Miles_per_Gallon', 
            y='Displacement', 
            hue='Weight_in_lbs')

# %%
sns.relplot(data=cars, 
            x='Miles_per_Gallon', 
            y='Displacement', 
            kind='line')
#Para ver las tendencias

# %% [markdown]
# # Joint

# %%
#Distribución bivariante
#Vemos como están distribuidos
sns.jointplot(data=cars,
             x='Displacement',
             y='Weight_in_lbs')

# %%
#Hace el contorn, vemos donde hay más densidad
sns.jointplot(data=cars,
             x='Displacement',
             y='Weight_in_lbs',
             kind='kde')

# %% [markdown]
# # Joint Grid

# %%
#Creamos la interfaz y añadimos el dataset y los ejes
sns.JointGrid(data=cars,
             x='Displacement',
             y='Weight_in_lbs')

# %%
grid=sns.JointGrid(data=cars,
             x='Displacement',
             y='Weight_in_lbs')

#Ploteamos los datos en la interfaz creada
grid.plot(sns.scatterplot, sns.distplot);
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histogram

# %%
sns.displot(data=cars, x='Miles_per_Gallon')

# %% [markdown]
# By default, displot()/histplot() choose a default bin size based on the variance of the data and the number of observations.
#
# But you should not be over-reliant on such automatic approaches, because they depend on particular assumptions about the structure of your data. It is always advisable to check that your impressions of the distribution are consistent across different bin sizes

# %%
sns.displot(data=cars, x='Miles_per_Gallon',
            kind='kde',
            rug=True)

# %%
sns.displot(data=cars, x='Miles_per_Gallon',
            kind='kde',
            rug=True,
           hue='Origin')

# %% [markdown]
# stat{“count”, “frequency”, “density”, “probability”}
# Aggregate statistic to compute in each bin.
#
# **count** shows the number of observations
#
# **frequency** shows the number of observations divided by the bin width
#
# **density** normalizes counts so that the area of the histogram is 1
#
# probability normalizes counts so that the sum of the bar heights is 1

# %% [markdown]
# # Pairwise relationships

# %%
sns.pairplot(cars)
#Plotea todas las variables cuantitativas, haciendo todos los pares de variables y la distribucion conjunta

# %%
#Para ampliar una de ellas
sns.relplot(data=cars, x='Miles_per_Gallon', y='Acceleration')

# %%
sns.pairplot(cars, hue='Origin', diag_kind='kde')

# %% [markdown]
# ### Linear relationships

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs')
#Linea de regresion

# %%
sns.lmplot(data=cars, x='Horsepower', y='Weight_in_lbs', hue='Origin')

# %% [markdown]
# # Categorical Data
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# #### swarm and strip plot
#
# https://github.com/allisonhorst/palmerpenguins

# %%
#Una variable tiene que ser categorica
sns.stripplot(data=cars, x='Origin', y='Horsepower')

# %%
sns.swarmplot(data=cars, x='Origin', y='Horsepower')
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=cars, x='Origin', y='Horsepower', hue='Cylinders')
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=cars, y='Origin', x='Horsepower', hue='Cylinders')
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 19.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/dsc/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
cars.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement',
#        'Horsepower', 'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
cars['Year']
# Out:
# 0      1970-01-01
# 1      1970-01-01
# 2      1970-01-01
# 3      1970-01-01
# 4      1970-01-01
# 5      1970-01-01
# 6      1970-01-01
# 7      1970-01-01
# 8      1970-01-01
# 9      1970-01-01
# 10     1970-01-01
# 11     1970-01-01
# 12     1970-01-01
# 13     1970-01-01
# 14     1970-01-01
# 15     1970-01-01
# 16     1970-01-01
# 17     1970-01-01
# 18     1970-01-01
# 19     1970-01-01
# 20     1970-01-01
# 21     1970-01-01
# 22     1970-01-01
# 23     1970-01-01
# 24     1970-01-01
# 25     1970-01-01
# 26     1970-01-01
# 27     1970-01-01
# 28     1970-01-01
# 29     1970-01-01
#           ...
# 376    1982-01-01
# 377    1982-01-01
# 378    1982-01-01
# 379    1982-01-01
# 380    1982-01-01
# 381    1982-01-01
# 382    1982-01-01
# 383    1982-01-01
# 384    1982-01-01
# 385    1982-01-01
# 386    1982-01-01
# 387    1982-01-01
# 388    1982-01-01
# 389    1982-01-01
# 390    1982-01-01
# 391    1982-01-01
# 392    1982-01-01
# 393    1982-01-01
# 394    1982-01-01
# 395    1982-01-01
# 396    1982-01-01
# 397    1982-01-01
# 398    1982-01-01
# 399    1982-01-01
# 400    1982-01-01
# 401    1982-01-01
# 402    1982-01-01
# 403    1982-01-01
# 404    1982-01-01
# 405    1982-01-01
# Name: Year, Length: 406, dtype: object

# %%
sns.relplot(data=cars, x='Year', y='Displacement', kind='line')

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(data=cars, x='Origin', y='Horsepower')

# %%
sns.boxenplot(data=cars, x='Origin', y='Horsepower')

# %%
sns.violinplot(data=cars, x='Origin', y='Horsepower')

# %%
sns.catplot(data=cars, x='Origin', y='Horsepower', kind='violin')

# %% [markdown]
# ### Ejercicio
#
# ![violinplot.PNG](data:image/png;base64,...)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.style.use('seaborn') 
sns.catplot(data=iris, x='species', y='sepal_length',
            kind='violin',
            order=['virginica',  'versicolor', 'setosa'])

# %% [markdown]
# Order by decreasing median

# %%
my_order = df.groupby(by=["species"])["sepal_length"].median().iloc[::-1].index
 
sns.catplot(x='species', y='sepal_length', kind='violin', data=iris, order=my_order)

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=iris, x='species', y='sepal_length')

# %%
sns.countplot(data=iris, x='species')

# %% [markdown]
# # Point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(data=cars, x='Cylinders', y='Horsepower',
             hue='Origin')
#Conecta
#Compara y representa aspectos de una encuesta, y si puntuan más unas cosas que otras
#Para ver perfiles

# %% [markdown]
# ### Heatmap

# %%
#correlación entre todas las variables el dataframe
cars.corr()
# Out:
#                   Unnamed: 0  Miles_per_Gallon  Cylinders  Displacement  \
# Unnamed: 0          1.000000          0.584880  -0.375485     -0.399098
# Miles_per_Gallon    0.584880          1.000000  -0.775396     -0.804203
# Cylinders          -0.375485         -0.775396   1.000000      0.951787
# Displacement       -0.399098         -0.804203   0.951787      1.000000
# Horsepower         -0.432135         -0.778427   0.844158      0.898326
# Weight_in_lbs      -0.327662         -0.831741   0.895220      0.932475
# Acceleration        0.303377          0.420289  -0.522452     -0.557984
#
#                   Horsepower  Weight_in_lbs  Acceleration
# Unnamed: 0         -0.432135      -0.327662      0.303377
# Miles_per_Gallon   -0.778427      -0.831741      0.420289
# Cylinders           0.844158       0.895220     -0.522452
# Displacement        0.898326       0.932475     -0.557984
# Horsepower          1.000000       0.866586     -0.697124
# Weight_in_lbs       0.866586       1.000000     -0.430086
# Acceleration       -0.697124      -0.430086      1.000000

# %%
sns.heatmap(cars.corr(), cmap='RdBu', annot=True, center=0.0)

# %% [markdown]
# # cluster map
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %%
gapminder = pd.read_csv('gapminder.csv')
gapminder.head()
# Out:
#    Unnamed: 0      country  income  health  population
# 0           0  Afghanistan    1925   57.63    32526562
# 1           1      Albania   10620   76.00     2896679
# 2           2      Algeria   13434   76.50    39666519
# 3           3      Andorra   46577   84.10       70473
# 4           4       Angola    7615   61.00    25021974

# %%
numerics = gapminder[['income','health', 'population']]
normalized = numerics/numerics.max()
normalized
# Out:
#        income    health  population
# 0    0.014487  0.685256    0.023638
# 1    0.079924  0.903686    0.002105
# 2    0.101101  0.909631    0.028826
# 3    0.350527  1.000000    0.000051
# 4    0.057309  0.725327    0.018184
# 5    0.158410  0.894174    0.000067
# 6    0.130527  0.906064    0.031552
# 7    0.058422  0.884661    0.002193
# 8    0.331555  0.972652    0.017419
# 9    0.334151  0.963139    0.006210
# 10   0.127833  0.866825    0.007088
# 11   0.171723  0.859691    0.000282
# 12   0.332172  0.941736    0.001001
# 13   0.023789  0.833532    0.116998
# 14   0.097714  0.901308    0.000207
# 15   0.131061  0.837099    0.006901
# 16   0.310362  0.956005    0.008211
# 17   0.063976  0.832342    0.000261
# 18   0.013772  0.778835    0.007907
# 19   0.060078  0.834721    0.000563
# 20   0.047375  0.859691    0.007794
# 21   0.074001  0.926278    0.002769
# 22   0.129413  0.789536    0.001644
# 23   0.116205  0.898930    0.151047
# 24   0.549403  0.935791    0.000308
# 25   0.123204  0.890606    0.005196
# 26   0.012448  0.746730    0.013158
# 27   0.005848  0.718193    0.008124
# 28   0.024587  0.813317    0.011321
# 29   0.021802  0.707491    0.016965
# ..        ...       ...         ...
# 157  0.029915  0.826397    0.029239
# 158  0.128879  0.838288    0.000395
# 159  0.045869  0.612366    0.000935
# 160  0.337846  0.975030    0.007107
# 161  0.422330  0.985731    0.006031
# 162  0.034897  0.835434    0.013446
# 163  0.019432  0.844233    0.006164
# 164  0.019349  0.754221    0.038858
# 165  0.109214  0.892985    0.049387
# 166  0.015699  0.860880    0.000861
# 167  0.010784  0.763734    0.005308
# 168  0.038148  0.838288    0.000077
# 169  0.226623  0.848989    0.000988
# 170  0.083732  0.919144    0.008178
# 171  0.145699  0.909631    0.057168
# 172  0.119396  0.807372    0.003905
# 173  0.012643  0.722949    0.028366
# 174  0.063585  0.857313    0.032574
# 175  0.457182  0.910820    0.006655
# 176  0.287672  0.967895    0.047030
# 177  0.401529  0.940547    0.233839
# 178  0.153811  0.919144    0.002494
# 179  0.042129  0.833532    0.021724
# 180  0.021915  0.772889    0.000192
# 181  0.118553  0.901308    0.022607
# 182  0.042317  0.909631    0.067910
# 183  0.032504  0.894174    0.003393
# 184  0.029253  0.803805    0.019499
# 185  0.030359  0.701070    0.011781
# 186  0.013554  0.713555    0.011339
#
# [187 rows x 3 columns]

# %%
sns.heatmap(normalized)

# %%
sns.clustermap(normalized)

# %% [markdown]
# # Altair Basics
#
# ![sss.PNG](data:image/png;base64,...)
#
# https://altair-viz.github.io/
#
# Altair is a declarative statistical visualization library for Python.
#
#  Altair's API is simple, friendly and consistent and built on top of the powerful Vega-Lite JSON specification. This elegant simplicity produces beautiful and effective visualizations with a minimal amount of code.
#
#
#  The key feature of this declarative approach is that the user is free to think about the data, rather than the mechanics of the visualization. Vega-Lite specifications are expressed in JavaScript Object Notation (JSON), a cross-platform format often used for storage of nested and/or hierarchical data. Altair builds a Python layer on top of this, so that rather than writing raw JSON strings the user can write declarative Python code.
#
#
#
#
#  **Altair provides a Python API for generating validated Vega-Lite specifications**

# %% [markdown]
#  ## What's the main difference with Matplotlib?
#
# Altair allows less customization and doesn't provide 3D visualization BUT :
#
# - It's Flexible
# - It's Interactive
# - It's intuitive and structured
# - It's based on Pandas not in numpy

# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading https://files.pythonhosted.org/packages/01/55/0bb2226e34f21fa549c3f4557b4f154a5632f61132a969da17c95ca8eab9/altair-4.1.0-py3-none-any.whl (727kB)
#     100% |████████████████████████████████| 737kB 2.2MB/s ta 0:00:01
# Requirement already satisfied: pandas>=0.18 in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (0.23.4)
# Requirement already satisfied: numpy in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (1.15.4)
# Requirement already satisfied: jinja2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (2.10)
# Requirement already satisfied: jsonschema in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (2.6.0)
# Requirement already satisfied: toolz in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (0.9.0)
# Requirement already satisfied: entrypoints in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair) (0.2.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from pandas>=0.18->altair) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /home/dsc/anaconda3/lib/python3.7/site-packages (from pandas>=0.18->altair) (2018.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dsc/anaconda3/lib/python3.7/site-packages (from jinja2->altair) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas>=0.18->altair) (1.12.0)
# Installing collected packages: altair
# Successfully installed altair-4.1.0

# %%
import altair as alt
alt.__version__
# Out:
# '4.1.0'

# %% [markdown]
# ## Example Matplotlib vs Altair

# %%
xs = np.linspace(0,10)
ys = 3*xs**2

plt.plot(xs,ys)

# %%
#Altair orientado a usarse con dataframe
alt_df = pd.DataFrame({'X':xs,'Y':ys})
alt_df.head()
# Out:
#           X         Y
# 0  0.000000  0.000000
# 1  0.204082  0.124948
# 2  0.408163  0.499792
# 3  0.612245  1.124531
# 4  0.816327  1.999167

# %%
alt.Chart(alt_df).mark_line().encode(x='X',y='Y')
# Out:
# alt.Chart(...)

# %% [markdown]
# # Example
#
# Let's build a very simple example with a simple made up dataset

# %%
cars_chart = alt.Chart(cars)

cars_chart.mark_point()
# Out:
# alt.Chart(...)

# %%
cars_chart.mark_point().encode(x='Miles_per_Gallon',
                              y='Displacement')
# Out:
# alt.Chart(...)

# %%
# Out:
# alt.Chart(...)

# %% [markdown]
# We have just defined the chart but have not tell the chart do anything with the data.
# We have to use the mark attribute of the chart object to specify how we want to visualize it
#
# `alt.Chart(data).mark_*`

# %% [markdown]
# Altair automatically recognizes the data type in the dataframe

# %%
cars_chart.mark_line().encode(x='Miles_per_Gallon',
                              y='Displacement')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example taking data from JSON

# %%
data.movies.url

# %%
import requests

response = requests.get(data.movies.url)
response.text()
movie_data = response.json()

# %%
movie.data[0]

# %%
movie_chart=alt.Chart(movie_data)
movie_chart.mark_point().encode(x='Production Budget',
                               y='IMD Rating')

# %%
movie_chart.mark_bar().encode(alt.X('Production Budget', bin= True, type='quantitative'), y='count()')

# %% [markdown]
# ## Example 2

# %% [markdown]
# https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html#altair.Chart

# %% [markdown]
# It can be especified using `alt.X`  instead.
#
# The type must also be specified:
# ['quantitative', 'ordinal', 'temporal', 'nominal']

# %% [markdown]
# https://altair-viz.github.io/user_guide/encoding.html#shorthand-description
#
#
# ![shorthand.PNG](data:image/png;base64,...)

# %% [markdown]
# # Streamlit

# %% [markdown]
# Streamlit is a new library that allow to transform simple python code to web apps easily
#
# https://www.streamlit.io/
#
# https://docs.streamlit.io/en/stable/getting_started.html
#
# https://docs.streamlit.io/en/stable/api.html

# %%
"""conda install streamlit -c conda-forge
pip install --upgrade numpy pillow
"""

# %%
"""!pip install streamlit"""
# Out:
# Collecting streamlit
#   Downloading https://files.pythonhosted.org/packages/c0/04/348652bb02a0b8b5f93951c228558e2021af89faeef7dec2aae2c63efb11/streamlit-0.74.1-py2.py3-none-any.whl (7.5MB)
#     100% |████████████████████████████████| 7.5MB 528kB/s ta 0:00:01  0% |▎                               | 71kB 247kB/s eta 0:00:30    14% |████▊                           | 1.1MB 370kB/s eta 0:00:18    17% |█████▊                          | 1.3MB 1.7MB/s eta 0:00:04    20% |██████▊                         | 1.6MB 745kB/s eta 0:00:08    30% |█████████▊                      | 2.3MB 597kB/s eta 0:00:09    36% |███████████▊                    | 2.8MB 515kB/s eta 0:00:10    45% |██████████████▋                 | 3.4MB 843kB/s eta 0:00:05    61% |███████████████████▋            | 4.6MB 1.5MB/s eta 0:00:02    63% |████████████████████▏           | 4.7MB 1.6MB/s eta 0:00:02    63% |████████████████████▎           | 4.8MB 1.2MB/s eta 0:00:03    66% |█████████████████████▍          | 5.0MB 3.6MB/s eta 0:00:01��████████████████████▊      | 6.0MB 4.7MB/s eta 0:00:010:01    84% |███████████████████████████     | 6.3MB 547kB/s eta 0:00:03    92% |█████████████████████████████▌  | 6.9MB 1.7MB/s eta 0:00:01    94% |██████████████████████████████▏ | 7.1MB 1.9MB/s eta 0:00:01    94% |██████████████████████████████▎ | 7.1MB 1.0MB/s eta 0:00:01    96% |██████████████████████████████▉ | 7.2MB 1.2MB/s eta 0:00:01    98% |███████████████████████████████▋| 7.4MB 2.8MB/s eta 0:00:01
# Collecting watchdog; platform_system != "Darwin" (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/5f/39/e9e2aa6f22983b682dda2daccd3151c706d3da66d989c78c038d6b94b962/watchdog-1.0.2.tar.gz (98kB)
#     100% |████████████████████████████████| 102kB 771kB/s a 0:00:01    93% |██████████████████████████████  | 92kB 738kB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (1.15.4)
# Collecting gitpython (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#     100% |████████████████████████████████| 163kB 906kB/s ta 0:00:01
# Requirement already satisfied: python-dateutil in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (2.7.5)
# Requirement already satisfied: requests in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (2.21.0)
# Requirement already satisfied: packaging in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (18.0)
# Requirement already satisfied: pandas>=0.21.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (0.23.4)
# Requirement already satisfied: tornado>=5.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (5.1.1)
# Collecting base58 (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/b8/a1/d9f565e9910c09fd325dc638765e8843a19fa696275c16cc08cf3b0a3c25/base58-2.1.0-py3-none-any.whl
# Collecting pillow>=6.2.0 (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/eb/8e/d2f7a67cf8da9b83c1e3ee38dbf49448f3c8acb2cb38f76e4301f4a70223/Pillow-8.1.0-cp37-cp37m-manylinux1_x86_64.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 555kB/s ta 0:00:01    51% |████████████████▌               | 1.1MB 1.4MB/s eta 0:00:01
# Collecting astor (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Collecting tzlocal (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/5d/94/d47b0fd5988e6b7059de05720a646a2930920fff247a826f61674d436ba4/tzlocal-2.1-py2.py3-none-any.whl
# Collecting protobuf!=3.11,>=3.6.0 (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/e0/dd/5c5d156ee1c4dba470d76dac5ae57084829b4e17547f28e9f636ce3fa54b/protobuf-3.14.0-cp37-cp37m-manylinux1_x86_64.whl (1.0MB)
#     100% |████████████████████████████████| 1.0MB 1.5MB/s ta 0:00:01    21% |██████▊                         | 215kB 663kB/s eta 0:00:02    39% |████████████▌                   | 399kB 1.7MB/s eta 0:00:01    49% |███████████████▊                | 501kB 1.1MB/s eta 0:00:01    51% |████████████████▍               | 522kB 1.4MB/s eta 0:00:01    74% |███████████████████████▊        | 757kB 6.1MB/s eta 0:00:01
# Collecting blinker (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/1b/51/e2a9f3b757eb802f61dc1f2b09c8c99f6eb01cf06416c0671253536517b6/blinker-1.4.tar.gz (111kB)
#     100% |████████████████████████████████| 112kB 616kB/s ta 0:00:01
# Collecting validators (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/db/2f/7fed3ee94ad665ad2c1de87f858f10a7785251ff75b4fd47987888d07ef1/validators-0.18.2-py3-none-any.whl
# Requirement already satisfied: altair>=3.2.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (4.1.0)
# Collecting toml (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl
# Collecting pyarrow; python_version < "3.9" (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/c8/58/d07e7ee8b0cffe509f9e5a3742e09636a4a58b2113d193166615b934846f/pyarrow-2.0.0-cp37-cp37m-manylinux1_x86_64.whl (16.9MB)
#     100% |████████████████████████████████| 16.9MB 426kB/s eta 0:00:01 1% |▋                               | 296kB 1.6MB/s eta 0:00:11    3% |█▎                              | 665kB 395kB/s eta 0:00:42    7% |██▍                             | 1.3MB 1.9MB/s eta 0:00:09    9% |███                             | 1.6MB 1.2MB/s eta 0:00:13    9% |███▏                            | 1.7MB 845kB/s eta 0:00:18    10% |███▍                            | 1.8MB 855kB/s eta 0:00:18    11% |███▋                            | 1.9MB 1.0MB/s eta 0:00:15    12% |████                            | 2.1MB 1.8MB/s eta 0:00:09    14% |████▉                           | 2.5MB 1.6MB/s eta 0:00:09    16% |█████▍                          | 2.8MB 1.1MB/s eta 0:00:13    21% |███████                         | 3.6MB 2.0MB/s eta 0:00:07    23% |███████▋                        | 4.0MB 4.7MB/s eta 0:00:03    25% |████████▏                       | 4.3MB 1.5MB/s eta 0:00:09    27% |████████▊                       | 4.6MB 653kB/s eta 0:00:19    27% |█████████                       | 4.7MB 520kB/s eta 0:00:24    29% |█████████▌                      | 5.0MB 103kB/s eta 0:01:55    33% |██████████▋                     | 5.6MB 5.1MB/s eta 0:00:03    42% |█████████████▋                  | 7.2MB 216kB/s eta 0:00:45    47% |███████████████▏                | 8.0MB 2.4MB/s eta 0:00:04    62% |████████████████████            | 10.6MB 5.0MB/s eta 0:00:02    63% |████████████████████▍           | 10.7MB 2.8MB/s eta 0:00:03    69% |██████████████████████▍         | 11.8MB 788kB/s eta 0:00:07    73% |███████████████████████▋        | 12.5MB 703kB/s eta 0:00:07    76% |████████████████████████▌       | 12.9MB 282kB/s eta 0:00:15    77% |████████████████████████▊       | 13.1MB 355kB/s eta 0:00:11    87% |████████████████████████████    | 14.8MB 1.5MB/s eta 0:00:02    90% |█████████████████████████████   | 15.2MB 3.8MB/s eta 0:00:01
# Collecting cachetools>=4.0 (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/92/da/d3c94fc7c72ad9298072681ec3e8cea86949acc5c4cce4290ba21f7050a8/cachetools-4.2.0-py3-none-any.whl
# Requirement already satisfied: click>=7.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from streamlit) (7.0)
# Collecting pydeck>=0.1.dev5 (from streamlit)
#   Downloading https://files.pythonhosted.org/packages/9e/9d/8fbf1f56cc5891e6c3295bf94fc176e9ab0a3ffdd090cc8b354ac2640f9a/pydeck-0.5.0-py2.py3-none-any.whl (4.5MB)
#     100% |████████████████████████████████| 4.5MB 1.3MB/s ta 0:00:011   12% |████                            | 563kB 2.4MB/s eta 0:00:02    27% |████████▉                       | 1.2MB 191kB/s eta 0:00:17    37% |████████████                    | 1.7MB 2.9MB/s eta 0:00:01    52% |████████████████▊               | 2.3MB 876kB/s eta 0:00:03    52% |████████████████▉               | 2.3MB 228kB/s eta 0:00:10    56% |██████████████████▏             | 2.5MB 1.5MB/s eta 0:00:02    72% |███████████████████████▎        | 3.2MB 1.6MB/s eta 0:00:01    78% |█████████████████████████       | 3.5MB 1.7MB/s eta 0:00:01    83% |██████████████████████████▋     | 3.7MB 1.6MB/s eta 0:00:01    90% |█████████████████████████████   | 4.0MB 1.3MB/s eta 0:00:01
# Collecting gitdb<5,>=4.0.1 (from gitpython->streamlit)
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#     100% |████████████████████████████████| 71kB 985kB/s ta 0:00:01    97% |███████████████████████████████▏| 61kB 1.5MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from python-dateutil->streamlit) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from packaging->streamlit) (2.3.0)
# Requirement already satisfied: pytz>=2011k in /home/dsc/anaconda3/lib/python3.7/site-packages (from pandas>=0.21.0->streamlit) (2018.7)
# Requirement already satisfied: decorator>=3.4.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from validators->streamlit) (4.3.0)
# Requirement already satisfied: entrypoints in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.2.3)
# Requirement already satisfied: toolz in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.9.0)
# Requirement already satisfied: jsonschema in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (2.6.0)
# Requirement already satisfied: jinja2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (2.10)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (7.4.2)
# Collecting ipykernel>=5.1.2; python_version >= "3.4" (from pydeck>=0.1.dev5->streamlit)
#   Downloading https://files.pythonhosted.org/packages/7d/cc/e8908bbb2921732f6851ebbbe4b77b925aab62e644ab9402f21c84fa6107/ipykernel-5.4.3-py3-none-any.whl (120kB)
#     100% |████████████████████████████████| 122kB 1.1MB/s ta 0:00:01
# Requirement already satisfied: traitlets>=4.3.2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (4.3.2)
# Collecting smmap<4,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->streamlit)
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dsc/anaconda3/lib/python3.7/site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (7.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.4.0)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.4.2)
# Requirement already satisfied: jupyter-client in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.2.4)
# Requirement already satisfied: ipython-genutils in /home/dsc/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.0.7)
# Requirement already satisfied: setuptools>=18.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (40.6.3)
# Requirement already satisfied: pygments in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.3.1)
# Requirement already satisfied: backcall in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/dsc/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.6.0)
# Requirement already satisfied: jupyter-core in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.4.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.7.4)
# Requirement already satisfied: pyzmq>=13 in /home/dsc/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (17.1.2)
# Requirement already satisfied: wcwidth in /home/dsc/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: nbconvert in /home/dsc/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.1)
# Requirement already satisfied: Send2Trash in /home/dsc/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: prometheus-client in /home/dsc/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: mistune>=0.8.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: bleach in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: testpath in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.2)
# Requirement already satisfied: defusedxml in /home/dsc/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: webencodings in /home/dsc/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: watchdog, blinker
#   Running setup.py bdist_wheel for watchdog ... done
#   Stored in directory: /home/dsc/.cache/pip/wheels/be/c0/c0/cce409bf15d5cf4c4000c93a3216ef3f7a9ffab7b6c0152dde
#   Running setup.py bdist_wheel for blinker ... done
#   Stored in directory: /home/dsc/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# Successfully built watchdog blinker
# pydeck 0.5.0 has requirement jinja2>=2.10.1, but you'll have jinja2 2.10 which is incompatible.
# pydeck 0.5.0 has requirement numpy>=1.16.4, but you'll have numpy 1.15.4 which is incompatible.
# Installing collected packages: watchdog, smmap, gitdb, gitpython, base58, pillow, astor, tzlocal, protobuf, blinker, validators, toml, pyarrow, cachetools, ipykernel, pydeck, streamlit
#   Found existing installation: Pillow 5.3.0
#     Uninstalling Pillow-5.3.0:
#       Successfully uninstalled Pillow-5.3.0
#   Found existing installation: ipykernel 5.1.0
#     Uninstalling ipykernel-5.1.0:
#       Successfully uninstalled ipykernel-5.1.0
# Successfully installed astor-0.8.1 base58-2.1.0 blinker-1.4 cachetools-4.2.0 gitdb-4.0.5 gitpython-3.1.12 ipykernel-5.4.3 pillow-8.1.0 protobuf-3.14.0 pyarrow-2.0.0 pydeck-0.5.0 smmap-3.0.4 streamlit-0.74.1 toml-0.10.2 tzlocal-2.1 validators-0.18.2 watchdog-1.0.2

# %%
import streamlit as st
st.__version__
# Out:
# '0.74.1'

# %%
st.write('holi')

# %%
# %%writefile app.py
hola que tal
mi lita para los reyes magos es...
Writting app.py
# Out:
# Overwriting app.py

# %%
from vega_datasets import data

# %%
# %%writefile app.py
import streamlit as st
from vega_datasets import data
import altair as alt
import time

st.write('# Bienvenidos a mi app')


name = st.text_input('Como te llamas guapi?')
country = st.selectbox('De que pais quieres ver datos?', ['USA','Europe','Japan'])

cars = data.cars()

subset = cars[cars['Origin']==country]
my_chart = alt.Chart(subset).mark_point().encode(x='Displacement', y='Horsepower')

st.altair_chart(my_chart)
# Out:
# Overwriting app.py

# %%
"""consola: import streamlit as st"""
# Out:
# 'consola: import streamlit as st'

# %% [markdown]
# # Bokeh
#
# Bokeh "is a Python interactive visualization library that targets
# modern web browsers for presentation".
#
# Two components: A Python backend and a JS frontend.
#
# The way we use it is to declare our graphs in Python.
#
# The Python objects will in turn generate a series of JSON objects that describe a _scenegraph_. The JS component will generate the actual visualization from that scenegraph. The upside of this is that we don't need to work with JS, but our visualizations will be browser-based and interactive
#
# https://bokeh.pydata.org/en/latest/docs/gallery.html
#
# https://bokeh.pydata.org/en/latest/

# %% [markdown]
# # Plotly
#
# https://www.analyticsvidhya.com/blog/2017/01/beginners-guide-to-create-beautiful-interactive-data-visualizations-using-plotly-in-r-and-python/
#
# Plotly is a multi-language tool for creating interactive visualizations. It's built on top  of D3.

# %% [markdown]
# ## Dash
#
# "Shiny for Python"

# %% [markdown]
# # Additional references
#
# [Matplotlib documentation](http://matplotlib.org/contents.html)
#
# [The matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html)
#
# [Matplotlib cheat sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Nicolas P. Rougier's matplotlib tutorial](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)
#
# [Anatomy of Matplotlib](https://github.com/matplotlib/AnatomyOfMatplotlib)
#
# [$\LaTeX$](https://www.latex-project.org/)
#
# [Python graph gallery](https://python-graph-gallery.com/)
#
# [Effective matplotlib](https://pbpython.com/effective-matplotlib.html)
#
# [Python Data Science Handbook](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb)
#
# [more plots](https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/)
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
#
#
# [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html)
#
# [Bokeh Tutorials](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb)
#
# [Dash](https://plot.ly/dash/)
#
# [Dash being spotted before release](https://www.reddit.com/r/Python/comments/6imhxa/plotly_has_just_released_dash_20_a_shinylike_tool/)
#
# [Facets](https://pair-code.github.io/facets/)
#
# [Facets release Google research blog entry](https://research.googleblog.com/2017/07/facets-open-source-visualization-tool.html)
#
# [A great Altair tutorial](https://github.com/altair-viz/altair-tutorial)
