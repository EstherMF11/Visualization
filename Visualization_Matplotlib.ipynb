# %% [markdown]
# # `matplotlib`
# ![c.png](data:image/png;base64,...)
#
#
# https://matplotlib.org/

# %%
#Importamos las librerias
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#Añadimos estilo a las gráficas directamente llamando a una libreria
plt.style.use('ggplot')

# %% [markdown]
# ## Simple plots

# %% [markdown]
# ### Line plots

# %%
xs = np.linspace(0,2*np.pi)
ss = np.sin(xs)
cs = np.cos(xs)

plt.plot(xs,ss)
plt.plot(xs,cs)

# %% [markdown]
# #### Exercise
#
# Plot the logistic function
#
#
# $$f(x) = \frac{e^x}{1 + e^x}$$
#
# Between -7 and 7

# %%
def logistic_function(x):
    """Restuns the logistic function when x data is introduced"""
    return (np.exp(x)/(1+np.exp(x)))

xs = np.linspace(-7,7)

plt.plot(xs,logistic_function(xs))

# %% [markdown]
# ### Scatter plots

# %%
plt.scatter([1,2,2],[4,5,6])

# %% [markdown]
# Here we are using a random noise ("jitter"
# ) added over the (perfectly following $f(x) = 2x + 20$) Y2 Series in order to get some noisier, more real-looking generated data.

# %%
rs = np.random.randn(120)
rs
# Out:
# array([-0.32971103, -0.34673178, -0.99962239,  0.41427665,  0.81948158,
#         0.3426608 , -2.32484905, -0.16427176,  2.14004661,  1.07447783,
#        -0.75309961, -0.4595739 ,  1.02022163,  0.26285915, -0.24821806,
#        -1.41063181, -0.31740984, -0.24623148, -0.69287684, -0.5009661 ,
#         0.96346136,  2.22836371,  1.4435638 , -0.65812132,  1.17482805,
#         0.67500388, -1.2022668 ,  0.38382322, -0.92036078,  0.23962574,
#         1.21622291,  0.35603496,  0.29667475, -0.00891479,  1.27033985,
#         1.37056924,  0.38197294, -0.66178687,  0.33162804, -0.13154362,
#        -0.60123828,  2.30888913, -0.06478118,  0.06802808, -0.21675405,
#         0.50165045, -0.32260905, -0.32423354, -0.10267335,  0.46995393,
#        -1.13710378, -0.90072548, -0.20518526,  0.08619967,  0.09402293,
#         0.1269019 , -2.17950992, -0.38069807,  1.08283977, -0.41847277,
#         0.71829101,  2.01672493, -0.40639799,  0.61607341, -1.31090789,
#        -0.55916681, -0.8504049 , -1.46970048,  0.72406435, -0.39998462,
#         0.41210885, -0.2625406 ,  1.31708776, -0.6982567 ,  1.31343394,
#         0.02349824,  0.76551156,  0.86240263, -0.97167374,  0.98133432,
#        -1.30095731, -1.87672499, -0.09943027,  1.02894135, -0.09198793,
#         0.74678503,  0.13309144, -0.77411581,  0.67263655, -2.02605397,
#        -0.54110445,  1.35412308,  0.85220673,  0.51217666,  1.4761277 ,
#         0.82472282, -0.26682335, -0.91498569,  1.88114865, -1.06929175,
#         0.45577488,  3.0959383 , -0.75791287,  0.89441772,  0.42930123,
#        -1.15818471, -0.28918939, -1.08676645, -0.67982936, -0.75705524,
#         0.17611149,  0.88886243, -0.61946916,  0.08260272,  1.15981809,
#        -0.35451534, -1.7679565 , -1.41051329, -0.57061174,  0.19064097])

# %%
#Cambiar a otra desviación estandar a aprox 20 y centrada en el 100
rs2 = rs * 20 + 100

ys = 1.2*rs2 + 50 
jitter = np.random.random(120) * 30 #120 es el numero de datos y 30 es la aplitud
ys2 = ys + jitter

plt.scatter(rs2,ys2)

# %%
plt.plot(rs2,ys2)

# %% [markdown]
# This is what happens if you make a line plot of unsorted data:

# %% [markdown]
# #### Exercise - 2
#
# Let's draw a circle using a scatter plot, afterwards fill it.
#
# $$r^2 = sen(\phi)^2 + cos(\phi)^2$$
#
# $$x=r \cdot cos(\phi)$$
# $$y=r \cdot sin(\phi)$$

# %%
theta = np.linspace(0,2*np.pi)
r = np.sin(theta)**2+np.cos(theta)**2
xs = r*np.cos(theta)
ys = r*np.sin(theta)

plt.scatter(xs,ys)

# %% [markdown]
# ### Bar plots
#
# Do not confuse with histograms
#
# A bar plot is a plot that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.
#
# A bar plot shows comparisons among discrete categories. One axis of the plot shows the specific categories being compared, and the other axis represents a measured value.

# %%
ys = [3,5,3,2]
labels = ['A','B','C','D']
xs = range(len(ys))

plt.bar(xs,ys)
#Damos nombre a los valores del eje x
plt.xticks(xs,labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7fa5ced991d0>,
#   <matplotlib.axis.XTick at 0x7fa5cebe2438>,
#   <matplotlib.axis.XTick at 0x7fa5cebe26a0>,
#   <matplotlib.axis.XTick at 0x7fa5ceed6e10>],
#  <a list of 4 Text xticklabel objects>)

# %%
ys = [3,5,3,2]
labels = ['corrisponding value for class A','corrisponding value for class B','corrisponding value for class C','corrisponding value for class D']
xs = range(len(ys))

plt.bar(xs,ys)
#Damos nombre a los valores del eje x
plt.xticks(xs,labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7fa5ce7ea550>,
#   <matplotlib.axis.XTick at 0x7fa5ceaabcf8>,
#   <matplotlib.axis.XTick at 0x7fa5ceaab860>,
#   <matplotlib.axis.XTick at 0x7fa5ce572240>],
#  <a list of 4 Text xticklabel objects>)

# %% [markdown]
# Observamos que el eje x es imposible de leer. Podemos cambiar la disposicion de la grafica al eje horizontal para poder visualizarlo y leerlo mejor.

# %%
#Barras horizontales
plt.barh(xs,ys)
plt.yticks(xs,labels)
# Out:
# ([<matplotlib.axis.YTick at 0x7fa5ce69b748>,
#   <matplotlib.axis.YTick at 0x7fa5ce69b080>,
#   <matplotlib.axis.YTick at 0x7fa5ce4dac50>,
#   <matplotlib.axis.YTick at 0x7fa5ce59e5f8>],
#  <a list of 4 Text yticklabel objects>)

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)


plt.bar(X, +Y1, edgecolor='white')
plt.bar(X, -Y2, edgecolor='white')

for x, y in zip(X, Y1):
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='right', va= 'bottom')

for x, y in zip(X, Y2):
    plt.text(x + 0.4, -y - 0.05, '%.2f' % y, ha='right', va= 'top')

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())

plt.show()

# %% [markdown]
# #### Histogram
# A histogram is an approximate representation of the distribution of numerical data.
#
# To construct a histogram, the first step is to "bin" (or "bucket") the range of values—that is, divide the entire range of values into a series of intervals—and then count how many values fall into each interval. The bins are usually specified as consecutive, non-overlapping intervals of a variable. The bins (intervals) must be adjacent, and are often (but not required to be) of equal size
#
# [Wikipedia](https://en.wikipedia.org/wiki/Histogram)

# %%
#Se forma una desviación ideal
xs = np.random.randn(230) * 40 + 120
plt.hist(xs);

#;para quitar el texto que sale abajo

# %%
plt.hist(xs, bins=25);
#Vemos mas ruido que en distribucion ideal

# %%
#Límites de las barras
plt.hist(xs,bins=[0, 12, 18, 65, 120, 180, 300])
# Out:
# (array([  0.,   0.,  16.,  91., 103.,  17.]),
#  array([  0,  12,  18,  65, 120, 180, 300]),
#  <a list of 6 Patch objects>)

# %% [markdown]
# ## The object-oriented interface
#
# Essential for finer control.
#
# The recommended procedure is to use pyplot to create figures and the object-oriented interface for plotting.
#
# We need to know the somewhat confusing [matplotlib terminology](http://matplotlib.org/faq/usage_faq.html#parts-of-a-figure)

# %% [markdown]
# ![Anatomy of a Matplotlib Figure](http://matplotlib.org/_images/anatomy1.png)

# %% [markdown]
# #### Figure
#
# A whole figure which may contain several Axes. It communicates with the `Canvas` for us.

# %%
#Cantidad de paneles que queremos
fig = plt.figure()

# %%
fig = plt.subplots(1,1)

# %%
fig, ax = plt.subplots(2,3)

# %% [markdown]
# #### Artists
#
# There are two types of Artists: primitives and containers. The primitives represent the standard graphical objects we want to paint onto our canvas: Line2D, Rectangle, Text, AxesImage, etc., and the containers are places to put them (Axis, Axes and Figure).
#
# https://matplotlib.org/users/artists.html

# %% [markdown]
# #### Axes vs Axis
#
# An `Axes` (yes, it looks like a plural noun but it's not, necessarily) is a single panel of a figure. An `Axes` contains generally 2, but sometimes 3, `Axis`. It is the object type we'll spend most time interacting with.
#
# `Axis` objects represent the lines in the x and y (and z in the case of 3D plots) dimensions. With them you can control ticks and ticklabels.

# %% [markdown]
# ### Interlude: the recommended interface for our plotting functions
#
# From [the matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html):
#
# ```python
# def my_plotter(ax, data1, data2, param_dict):
#     """
#     A helper function to make a graph
#
#     Parameters
#     ----------
#     ax : Axes
#         The axes to draw to
#
#     data1 : array
#        The x data
#
#     data2 : array
#        The y data
#
#     param_dict : dict
#        Dictionary of kwargs to pass to ax.plot
#
#     Returns
#     -------
#     out : list
#         list of artists added
#     """
#     out = ax.plot(data1, data2, **param_dict)
#     return out
# ```

# %%
xs = np.linspace(0,20)
exp = np.exp(xs)

plt.plot(xs,exp)
plt.xlabel('exponencial')
plt.xlim(15,18)
# Out:
# (15, 18)

# %%
f,ax=plt.subplots(2,2)
plt.plot(xs,exp)
plt.xlabel('exponencial')
# Out:
# Text(0.5, 0, 'exponencial')

# %%
def my_plotter(axes, data1, data2, **param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = axes.plot(data1, data2, **param_dict)
    axes.set_xlim(-5,5)
    return out

f,ax = plt.subplots(2,2)
my_plotter(ax[0,0],xs,exp)

# %% [markdown]
# ## `add_axes()`, `add_subplot`, and `subplots()`
#
# We can add Axes to a Figure by calling its add_axes method.
#
# A subplot is just an Axes that we place within an imaginary grid.
#
# For even finer control we can use [GridSpec](http://matplotlib.org/api/gridspec_api.html)

# %%
def generate_points(mu, sigma, A, B, npoints=150):
    xs = np.random.randn(npoints)*sigma+mu
    ys = A*xs+B+np.random.randn(npoints)*B/2
    return xs,ys

# %%
xs,ys = generate_points(5,2,1.2,2)

# %% [markdown]
# ### `add_axes()`
#
# See https://matplotlib.org/users/artists.html
#
# Total flexibility in placing the Axes: we specify `[left, bottom, width, height]` in 0-1 relative figure coordinates.

# %%
f = plt.figure()
axes = f.add_axes([.2,.3,.4,.4]) #left, bottom, width, height
axes = f.add_axes([.5,.5,.5,.5]) #left, bottom, width, height

#Esta situado en el punto 20% con respecto al eje izq, 30% con abajo, 40% de anchura y un 40% de altura

# %%
#Ocupa toda la figura
f = plt.figure()
axes = f.add_axes([0,0,1,1]) #left, bottom, width, height
axes.scatter(xs,ys)

axes2 = f.add_axes([.55,0,.45,0.4])
axes2.scatter(xs,ys)

# %% [markdown]
# ### Subplots
#
# We can add them with either `figure.add_subplot()` or create a figure with its subplots directly by calling `plt.subplots()`

# %% [markdown]
# ### `figure.subplots()`

# %%
#Manera recomendada para crear subplots!!!
f, ax = plt.subplots(2,2)

f.set_size_inches(12,6) #tamaño en pulgadas global de la figura

#Con esto me he creado los objetos que quiero

ax[0,0].scatter(xs,ys)
ax[0,1].hist(xs)
ax[1,0].scatter(xs,np.exp(xs))
ax[1,1].bar([1,2,4],[5,8,3]);

# %% [markdown]
# This is probably the most convenient way of working with the object-oriented interface

# %%
f = plt.figure()
ax = f.add_subplot(2,2,1)
ax.hist(xs)

ax = f.add_subplot(2,2,4)
ax.scatter(xs,ys)

# %%
f = plt.figure()
ax = f.add_subplot(2,2,1)
ax.hist(xs)

ax = f.add_subplot(1,2,2)
ax.scatter(xs,ys)

# %% [markdown]
# ### Sharing axis

# %%
f,ax = plt.subplots(2,2,sharex=True,sharey=True) #Fijamos ejes x y eje y 
ax[0,0].scatter(xs,ys)
ax[0,1].scatter(xs,np.log1p(xs))

# %% [markdown]
# ### Gridspec

# %%
f = plt.figure()
f.set_size_inches(12,6)
spec = f.add_gridspec(3,3,width_ratios=[2,5,6],height_ratios=[1,3,2])

for i in range(3):
    for j in range(3):
        f.add_subplot(spec[i,j])

# %% [markdown]
# ## `fill_between`
#
# We can fill areas of the plot with solid color
#
# The syntax is
#
# ```python
# plt.fill_between(X, Y1, Y2)
# ```
#
# Where Y1 and Y2 are either `np.array`s or scalar values.

# %%
x = [1,2,3]
y1 = [2,3,7]
y2 = [5,6,8]

plt.fill_between(x,y1,y2)
plt.plot(x,y1)
plt.plot(x,y2)

# %% [markdown]
# ## `fill_between`(`where=`)
#
# We can fill areas of the plot with solid color differently in different parts of the graph.
#
# The syntax is
#
# ```python
# plt.fill_between(X, Y1, Y2, where=boolean_array)
# ```
#
# Where Y1 and Y2 are either `np.array`s or scalar values, and boolean_array can be constructed from X, from Y, or from whatever you want.

# %%
xs = np.linspace(-3,3)
ys_1 = 2.4 * xs + 5 #Lineal
ys_2 = xs**2 #Cuadratica
plt.fill_between(xs,ys_1,ys_2)

# %%
xs = np.linspace(-3,3)
ys_1 = 2.4 * xs + 5 #Lineal
ys_2 = xs**2 #Cuadratica
plt.fill_between(xs,ys_1,ys_2,where=ys_1>ys_2)

# %%
ys_1>ys_2
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
plt.plot(xs,ys_1,color='blue')

# %%
xs, ys = generate_points(4,2,1.2,3)

plt.scatter(xs,ys,alpha=0.3)
#alpha es la opacidad del color

# %% [markdown]
# #### Exercise:
# Given this code:
# ```python
# n = 256
# X = np.linspace(-np.pi,np.pi,n,endpoint=True)
# Y = np.sin(2*X)
#
# plt.plot (X, Y+1, color='blue', alpha=1.00)
# plt.plot (X, Y-1, color='blue', alpha=1.00)
# plt.show()
# ```
#
# Reproduce this plot:
#
# ![Exercise](data:image/png;base64,...)

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.plot (X, Y+1, color='blue', alpha=1.00)
plt.plot (X, Y-1, color='blue', alpha=1.00)

plt.show()

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.axes([0.025,0.025,0.95,0.95])
plt.plot (X, Y+1, color='blue', alpha=1.00)
#Ponemos el 1 porque le marcamos desde donde queremos que empieze a colorear
plt.fill_between(X,Y+1,y2=1,color='blue',alpha=.25)  #Ponemos 1 porque es el punto desde el que queremos pintar
plt.plot (X, Y-1, color='blue', alpha=1.00)
#Ponemos el -1 porque le marcamos desde donde queremos que empieze a colorear
#Ponemos el where para especificar los rangos en los que queremos que coloree
plt.fill_between(X,Y-1,y2=-1,where=(Y-1)>-1,color='blue',alpha=.25) 
plt.fill_between(X,Y-1,-1,where=(Y-1)<-1,color='red',alpha=.25)

plt.xlim(-np.pi,np.pi)
plt.xticks(())
plt.ylim(-2.5, 2.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ## Line properties

# %% [markdown]
# ### Color
#
# https://matplotlib.org/tutorials/colors/colors.html

# %%
plt.plot(X,Y, color='grey')

plt.plot(X-.5,Y, color='g')

plt.plot(X-1,Y, color='.75')

plt.plot(X-2,Y, color='#0099FF') #Hexadecimal > #RRGGBB
#REDREDGREENGREENBLUEBLUE

plt.plot(X-2.25,Y, color=(.5,.2,.1))

plt.plot(X-2.5,Y, color='chartreuse')

# %%
plt.scatter(X,Y,c=Y)#Para que cada uno de los puntos tenga un valor

plt.colorbar() #Añadimos la paleta de colores

# %% [markdown]
# ### Colormaps
#
# See https://matplotlib.org/users/colormaps.html
#
# You need to choose the appropriate color.
#
# Often, for powerful visualizations it's good to use a muted palette for most of the visualization and reserve one or two accent colors for the points that you want the audience to concentrate on.
#
# If you want to use color to encode variables, choose the appropriate colormap according to the kind of variable that you want to encode.
#
#
# #### Sequential
#
# ![Sequential Colormaps](https://matplotlib.org/_images/grayscale_01_00.png)
#
# #### Divergent
#
# ![Divergent Colormaps](https://matplotlib.org/_images/sphx_glr_colormaps_004.png)
#
# #### Qualitative
#
# ![Qualitative Colormaps](https://matplotlib.org/_images/sphx_glr_colormaps_006.png)

# %% [markdown]
# #### Exercise
#
# Given this code, try to reproduce this graphic taking care of marker size, color and transparency.
#
# ```python
# n = 1024
# X = np.random.normal(0,1,n)
# Y = np.random.normal(0,1,n)
#
# plt.scatter(X,Y)
# plt.show()
# ```
#
# ![Color exercise](data:image/png;base64,...)

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

plt.scatter(X,Y)
plt.show()

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)


color = np.arctan2(Y,X)  #Trigonometria arcotangente 2

plt.axes([0.025,0.025,0.95,0.95])

plt.scatter(X,Y, s=50, c=color, alpha=.5)

plt.xlim(-1.5,1.5)
plt.xticks(())
plt.ylim(-1.5,1.5)
plt.yticks(())
plt.show()

# %% [markdown]
# **T = np.arctan2(Y,X)**
#
# * *arctan2(y,x)*: devuelve la tangente de arco de los dos números x y y. Es similar al cálculo de la arcotangente de y / x, excepto que los signos de ambos argumentos se utilizan para determinar el cuadrante del resultado. El resultado es un ángulo expresado en radianes. Es decir, es el ángulo en radianes entre el punto que termina en el origen y pasa por el punto (1,0), y el rayo que termina en el origen y pasa por el punto (x2, x1).
#
# **plt.scatter(X,Y, s=25, c=color, alpha=.5)**
#
# * *s* : tamaño de los puntos
#
# * *c* : color o secuencia de color

# %% [markdown]
# ### Markers and linestyles

# %% [markdown]
# While most ``plt`` functions translate directly to ``ax`` methods (such as ``plt.plot()`` → ``ax.plot()``, ``plt.legend()`` → ``ax.legend()``, etc.), this is not the case for all commands.
# In particular, functions to set limits, labels, and titles are slightly modified.
# For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:
#
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``
#
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ``ax.set()`` method to set all these properties at once:

# %%
f, ax = plt.subplots(1, 1)

xs = np.linspace(-1,1)
ys_1 = 1 * xs
ys_2 = xs ** 2
ys_3 = xs ** 3

ax.plot(xs, ys_1, 'r-.')
ax.plot(xs, ys_2, 'g.')
ax.plot(xs, ys_3, linestyle=':', color='fuchsia')


ax.set(xlim=(-.5,.5),ylim=(-.5,.5),title='superchart')
# Out:
# [(-0.5, 0.5), (-0.5, 0.5), Text(0.5, 1.0, 'superchart')]

# %% [markdown]
# ## Other attributes
#
# http://nbviewer.jupyter.org/github/WeatherGod/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part3-HowToSpeakMPL.ipynb

# %% [markdown]
# ## Text and Math: $\LaTeX$
#
# $\LaTeX$ is "a high-quality typesetting system; it includes features designed for the production of technical and scientific documentation. LaTeX is the de facto standard for the communication and publication of scientific documents" ([$LaTeX$ project website](https://www.latex-project.org/)).
#
# It's widely used for writing mathematical equations that need to be rendered accurately.
#
# We can use it in pretty much any place we need to use text.
#
# This is a standalone formula
#
# $$f(x,a) = \frac{x^{2a}}{3}$$
#
#
# This is an inline expression: $\sqrt{3}$, which you can use in matplotlib charts.

# %% [markdown]
# [Different font families](https://www.oreilly.com/library/view/matplotlib-2x-by/9781788295260/9af01705-e09c-4d1e-a036-ca0260d5003b.xhtml).
#
#
# *  'serif': Serifs are small decorative flourishes attached to stroke ends of characters. Fonts such as Times New Roman, Century, Garamond, and Palatino are serif fonts.
# *  'sans-serif': This means without serif. Fonts such as Helvetica, Arial, Calibri, and DejaVu Sans are sans-serif.
# *  'monospace': Monospace fonts have characters of the same width. They are usually used for code.
# * 'cursive': Cursive features connected brush strokes, usually in italic, that give a sense of classical elegance.
# * 'fantasy': Decorative fonts that look funny.

# %% [markdown]
# ## Legends

# %% [markdown]
# #### Exercises
#
# ![image.png](data:image/png;base64,...)

# %%
plt.style.use('seaborn')
f, ax = plt.subplots(2,1)
f.set_size_inches(12,6)
xs = np.linspace(0,1)

#Primer panel
for n in range(1,5):
    ax[0].plot(xs,xs**n, label=f'n={n}')

ax[0].legend(title='legend', loc='upper left')

#Segundo panel
ax[1].plot(xs,xs**2, label='multiline')
pi_medios = np.linspace(0, np.pi/2)
ax[1].plot(np.sin(pi_medios),np.cos(pi_medios), label='$\dfrac{1}{2}\pi$')
ax[1].plot(xs,2**(xs**2),label='$2{x^2}$')

ax[1].legend(loc='upper left')

# %%
plt.legend(loc='upper left')

# %% [markdown]
# ## Styles

# %%
plt.style.available
# Out:
# ['seaborn-dark-palette',
#  'seaborn-notebook',
#  'fivethirtyeight',
#  'seaborn-dark',
#  'fast',
#  'Solarize_Light2',
#  'grayscale',
#  'seaborn',
#  'seaborn-muted',
#  'seaborn-colorblind',
#  'seaborn-darkgrid',
#  'tableau-colorblind10',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'seaborn-paper',
#  'classic',
#  'seaborn-white',
#  'seaborn-talk',
#  'dark_background',
#  'ggplot',
#  'seaborn-ticks',
#  'bmh',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-deep',
#  '_classic_test']

# %%
plt.style.use('seaborn')

plt.plot(xs, xs**3)
plt.plot(xs, xs**2)
plt.plot(xs, xs**4)

plt.gca().set_title('holi')
plt.gcf().set_size_inches(10,6)

# %%
plt.style.use('fivethirtyeight')

plt.plot(xs, xs**3)
plt.plot(xs, xs**2)
plt.plot(xs, xs**4)

plt.gca().set_title('holi')
plt.gcf().set_size_inches(10,6)

# %% [markdown]
# ## Ticks, tick labels, limits

# %% [markdown]
# ### Ticks

# %%
plt.style.use('seaborn')

f,ax = plt.subplots(1,1)
ax.plot(xs, xs**3)
ax.plot(xs, xs**2)
ax.plot(xs, xs**4)

ax.set_title('holi')
f.set_size_inches(10,6)

ax.set_xticks(np.linspace(0,1,11))
# Out:
# [<matplotlib.axis.XTick at 0x7fa5cc96d320>,
#  <matplotlib.axis.XTick at 0x7fa5cc96d160>,
#  <matplotlib.axis.XTick at 0x7fa5c915be80>,
#  <matplotlib.axis.XTick at 0x7fa5cde93908>,
#  <matplotlib.axis.XTick at 0x7fa5cdebbc50>,
#  <matplotlib.axis.XTick at 0x7fa5cdebbd68>,
#  <matplotlib.axis.XTick at 0x7fa5cdebbac8>,
#  <matplotlib.axis.XTick at 0x7fa5cd1e2d30>,
#  <matplotlib.axis.XTick at 0x7fa5cd1e2b00>,
#  <matplotlib.axis.XTick at 0x7fa5cd1e2390>,
#  <matplotlib.axis.XTick at 0x7fa5cd1e20f0>]

# %% [markdown]
# ### Tick labels

# %%
plt.style.use('seaborn')

f,ax = plt.subplots(1,1)
ax.plot(xs, xs**3)
ax.plot(xs, xs**2)
ax.plot(xs, xs**4)

ax.set_title('holi')
f.set_size_inches(10,6)

ax.set_xticks(np.linspace(0,1,11))
ax.set_xticklabels(list('abcdefghijk'));

# %% [markdown]
# ### Limits

# %%
plt.style.use('seaborn')

f,ax = plt.subplots(1,1)
ax.plot(xs, xs**3)
ax.plot(xs, xs**2)
ax.plot(xs, xs**4)

ax.set_title('holi')
f.set_size_inches(10,6)

ax.set_xticks(np.linspace(0,1,11))
ax.set_xticklabels(list('abcdefghijk'));

ax.set_xlim((-1,2))
ax.set_ylim((.2,.4))
# Out:
# (0.2, 0.4)

# %% [markdown]
# ### Axis scales
#
#
# ![imagen.png](data:image/png;base64,...)

# %%
plt.style.use('seaborn')

f,ax = plt.subplots(1,1)
ax.plot(xs, xs**3)
ax.plot(xs, xs**2)
ax.plot(xs, xs**4)

ax.set_title('holi')
f.set_size_inches(10,6)

ax.set_xticks(np.linspace(0,1,11))
ax.set_xticklabels(list('abcdefghijk'));

ax.set_yscale('log')

# %% [markdown]
# ### Saving Figures to File
#
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats. Saving a figure can be done using the ``savefig()`` command.

# %%
plt.style.use('seaborn')

f,ax = plt.subplots(1,1)
ax.plot(xs, xs**3)
ax.plot(xs, xs**2)
ax.plot(xs, xs**4)

ax.set_title('holi')
f.set_size_inches(10,6)

ax.set_xticks(np.linspace(0,1,11))
ax.set_xticklabels(list('abcdefghijk'));

ax.set_yscale('log')

plt.savefig('current_figure.png')
plt.savefig('current_figure.pdf')
# !ls -l
# Out:
# total 1608
# -rw-rw-r-- 1 dsc dsc 1155030 ene 15 21:30 06-visualization-I_EMF.ipynb
# -rw-rw-r-- 1 dsc dsc  445142 ene 15 17:13 07-visualization-II.empty.ipynb
# -rw-rw-r-- 1 dsc dsc   12266 ene 15 21:32 current_figure.pdf
# -rw-rw-r-- 1 dsc dsc   26536 ene 15 21:31 current_figure.png
# -rw-rw-r-- 1 dsc dsc    2487 ene 15 17:06 Untitled.ipynb

# %% [markdown]
# ### Contour plots
#
# For representing one variable that is a function of other 2

# %%
plt.style.use('ggplot')

xs = np.linspace(-2*np.pi, 2*np.pi, num=100)
ys = np.linspace(0,4*np.pi, num=80)

X, Y = np.meshgrid(xs, ys)

# %%
X.shape, Y.shape
# Out:
# ((80, 100), (80, 100))

# %%
Z = np.sin(X) + np.cos(Y)

# %%
plt.contour(X,Y,Z, levels=20, cmap='RdBu')

# %%
plt.contour(X, Y, Z, levels=20, colors='black')

# %%
plt.contour(X, Y, Z, levels=20, cmap='RdBu')

# %%
plt.contourf(X, Y, Z, levels=20, cmap='RdBu')

# %%
plt.imshow(Z)

# %% [markdown]
# There are a few potential gotchas with ``imshow()``, however:
#
# - ``plt.imshow()`` doesn't accept an *x* and *y* grid, so you must manually specify the *extent* [*xmin*, *xmax*, *ymin*, *ymax*] of the image on the plot.
# - ``plt.imshow()`` by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
# - ``plt.imshow()`` will automatically adjust the axis aspect ratio to match the input data; this can be changed by setting, for example, ``plt.axis(aspect='image')`` to make *x* and *y* units match.

# %% [markdown]
# **Para poner una imagen guardada**
# ![Imagen importada](current_figure.png)

# %% [markdown]
# ## All together

# %%
t = np.arange(0.1, 20, 0.1)

y1 = np.sin(t)/t
y2 = np.sin(t)*np.exp(-t)
p1, p2 = plt.plot(t, y1, t, y2)

# Texto en la gráfica en coordenadas (x,y)
texto1 = plt.text(2, 0.6, r'$\frac{\sin(x)}{x}$', fontsize=20)
texto2 = plt.text(13, 0.2, r'$\sin(x) \cdot e^{-x}$', fontsize=16)


plt.title('Representacion de dos funciones')
plt.xlabel('Tiempo / s')
plt.ylabel('Amplitud / cm')

plt.grid(b=None)
# Punto a señalar en la primera gráfica
px = 7.5
py = np.sin(px)/px

# Pinto las coordenadas con un punto negro
punto = plt.plot([px], [py], 'ko')

# Hago un señalización con flecha
nota = plt.annotate(r'$\frac{\sin(7.5)}{\exp(-7.5)} = 0.12$',
         xy=(px, py),
         xycoords='data',
         xytext=(4, 0.4),
         fontsize=12,
         arrowprops=dict())

plt.show()

# %% [markdown]
# ### A note about 3D
#
# Never use 3D plots in a flat medium. That is all.

# %% [markdown]
# # Additional references
#
# [Matplotlib documentation](http://matplotlib.org/contents.html)
#
# [The matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html)
#
# [Matplotlib cheat sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Nicolas P. Rougier's matplotlib tutorial](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)
#
# [Anatomy of Matplotlib](https://github.com/matplotlib/AnatomyOfMatplotlib)
#
# [$\LaTeX$](https://www.latex-project.org/)
#
# [A quick look at altair](http://fernandoi.cl/blog/posts/altair/)
#
#
# [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html)
#
# [Bokeh Tutorials](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb)
#
# [Dash](https://plot.ly/dash/)
#
# [Dash being spotted before release](https://www.reddit.com/r/Python/comments/6imhxa/plotly_has_just_released_dash_20_a_shinylike_tool/)
#
# [Facets](https://pair-code.github.io/facets/)
#
# [Facets release Google research blog entry](https://research.googleblog.com/2017/07/facets-open-source-visualization-tool.html)
